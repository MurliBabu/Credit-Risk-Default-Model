# %% [markdown]
# Market Risk
#
# The dataset contains 6 years of information(weekly stock information) on the stock prices of 10 different Indian Stocks. Calculate the mean and standard deviation on the stock returns and share insights.
# Please find attached the files to be referred.
#
# Market Risk Dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
color = sns.color_palette()
import sklearn.metrics as metrics
from sklearn.tree import DecisionTreeClassifier
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix

# %% [markdown]
# Top 5 rows of the data

# %%
df = pd.read_csv("Market+Risk+Dataset.csv")
df.head()
# Out:
#          Date  Infosys  Indian Hotel  Mahindra & Mahindra  Axis Bank  SAIL  \
# 0  31-03-2014      264            69                  455        263    68
# 1  07-04-2014      257            68                  458        276    70
# 2  14-04-2014      254            68                  454        270    68
# 3  21-04-2014      253            68                  488        283    68
# 4  28-04-2014      256            65                  482        282    63
#
#    Shree Cement  Sun Pharma  Jindal Steel  Idea Vodafone  Jet Airways
# 0          5543         555           298             83          278
# 1          5728         610           279             84          303
# 2          5649         607           279             83          280
# 3          5692         604           274             83          282
# 4          5582         611           238             79          243

# %% [markdown]
# Last 5 rows of the data

# %%
df.tail()
# Out:
#            Date  Infosys  Indian Hotel  Mahindra & Mahindra  Axis Bank  SAIL  \
# 309  02-03-2020      729           120                  469        658    33
# 310  09-03-2020      634           114                  427        569    30
# 311  16-03-2020      577            90                  321        428    27
# 312  23-03-2020      644            75                  293        360    21
# 313  30-03-2020      633            75                  284        379    23
#
#      Shree Cement  Sun Pharma  Jindal Steel  Idea Vodafone  Jet Airways
# 309         23110         401           146              3           22
# 310         21308         384           121              6           18
# 311         18904         365           105              3           16
# 312         17666         338            89              3           14
# 313         17546         352            82              3           14

# %% [markdown]
# Shape of the data

# %%
df.shape
# Out:
# (314, 11)

# %% [markdown]
# Describe the data

# %%
df.describe()
# Out:
#           Infosys  Indian Hotel  Mahindra & Mahindra   Axis Bank        SAIL  \
# count  314.000000    314.000000           314.000000  314.000000  314.000000
# mean   511.340764    114.560510           636.678344  540.742038   59.095541
# std    135.952051     22.509732           102.879975  115.835569   15.810493
# min    234.000000     64.000000           284.000000  263.000000   21.000000
# 25%    424.000000     96.000000           572.000000  470.500000   47.000000
# 50%    466.500000    115.000000           625.000000  528.000000   57.000000
# 75%    630.750000    134.000000           678.000000  605.250000   71.750000
# max    810.000000    157.000000           956.000000  808.000000  104.000000
#
#        Shree Cement   Sun Pharma  Jindal Steel  Idea Vodafone  Jet Airways
# count    314.000000   314.000000    314.000000     314.000000   314.000000
# mean   14806.410828   633.468153    147.627389      53.713376   372.659236
# ...

# %% [markdown]
# Columns names

# %%
df.columns
# Out:
# Index(['Date', 'Infosys', 'Indian Hotel', 'Mahindra & Mahindra', 'Axis Bank',
#        'SAIL', 'Shree Cement', 'Sun Pharma', 'Jindal Steel', 'Idea Vodafone',
#        'Jet Airways'],
#       dtype='object')

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['dates'] = [pd.to_datetime(d) for d in df['Date']]

# %% [markdown]
# Checking for duplicate values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Datatypes details

# %%
df.dtypes
# Out:
# Date                   datetime64[ns]
# Infosys                         int64
# Indian Hotel                    int64
# Mahindra & Mahindra             int64
# Axis Bank                       int64
# SAIL                            int64
# Shree Cement                    int64
# Sun Pharma                      int64
# Jindal Steel                    int64
# Idea Vodafone                   int64
# Jet Airways                     int64
# dates                  datetime64[ns]
# dtype: object

# %% [markdown]
# Info of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 314 entries, 0 to 313
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 314 non-null    datetime64[ns]
#  1   Infosys              314 non-null    int64
#  2   Indian Hotel         314 non-null    int64
#  3   Mahindra & Mahindra  314 non-null    int64
#  4   Axis Bank            314 non-null    int64
#  5   SAIL                 314 non-null    int64
#  6   Shree Cement         314 non-null    int64
#  7   Sun Pharma           314 non-null    int64
#  8   Jindal Steel         314 non-null    int64
#  9   Idea Vodafone        314 non-null    int64
#  10  Jet Airways          314 non-null    int64
#  11  dates                314 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), int64(10)
# memory usage: 29.6 KB

# %% [markdown]
# Outlier Treatment

# %%
df_num= df.select_dtypes(include=['float64','int64'])

# %%
data_plot=df_num
fig=plt.figure(figsize=(30,30))
for i in range(0,len(data_plot.columns)):
    ax=fig.add_subplot(13,5,i+1)
    sns.boxplot(data_plot[data_plot.columns[i]])
    ax.set_title(data_plot.columns[i],color='Red')
plt.tight_layout()

# %%
def treat_outlier(x):

    q5= np.percentile(x,5)
    q25=np.percentile(x,25)
    q75=np.percentile(x,75)
    dt=np.percentile(x,95)
   
    IQR=q75-q25
    
    lower_bound=q25-(1.5*IQR)
    upper_bound=q75+(1.5*IQR)

    return x.apply(lambda y: q5 if y < lower_bound else y).apply(lambda y: dt if y > upper_bound else y)

# %%
def print_outlier(x):
    
    q5= np.percentile(x,5)
    q25=np.percentile(x,25)
    q75=np.percentile(x,75)
    dt=np.percentile(x,95)
    min_val = min(x)
    max_val = max(x)
   
    IQR=q75-q25
    
    lower_bound=q25-(1.5*IQR)
    upper_bound=q75+(1.5*IQR)
 
    return ('5%=',q5,'Q1=',q25,'Q3=',q75,'IQR=',IQR,'LL=',lower_bound,'UL=', upper_bound, '95%', dt, 'max=',max_val, 'min=',min_val)

# %%
for i in df_num.columns:    
    df_num[i]=treat_outlier(df_num[i])

# %%
data_plot=df_num
fig=plt.figure(figsize=(30,30))
for i in range(0,len(data_plot.columns)):
    ax=fig.add_subplot(13,5,i+1)
    sns.boxplot(data_plot[data_plot.columns[i]])
    ax.set_title(data_plot.columns[i],color='Red')
plt.tight_layout()

# %% [markdown]
# Missing Value Treatment

# %%
df.isnull().sum()
# Out:
# Date                   0
# Infosys                0
# Indian Hotel           0
# Mahindra & Mahindra    0
# Axis Bank              0
# SAIL                   0
# Shree Cement           0
# Sun Pharma             0
# Jindal Steel           0
# Idea Vodafone          0
# Jet Airways            0
# dates                  0
# dtype: int64

# %% [markdown]
# Univariate Analysis

# %%
df.hist(figsize=(20,30))
# Out:
# array([[<AxesSubplot:title={'center':'Date'}>,
#         <AxesSubplot:title={'center':'Infosys'}>,
#         <AxesSubplot:title={'center':'Indian Hotel'}>],
#        [<AxesSubplot:title={'center':'Mahindra & Mahindra'}>,
#         <AxesSubplot:title={'center':'Axis Bank'}>,
#         <AxesSubplot:title={'center':'SAIL'}>],
#        [<AxesSubplot:title={'center':'Shree Cement'}>,
#         <AxesSubplot:title={'center':'Sun Pharma'}>,
#         <AxesSubplot:title={'center':'Jindal Steel'}>],
#        [<AxesSubplot:title={'center':'Idea Vodafone'}>,
#         <AxesSubplot:title={'center':'Jet Airways'}>,
#         <AxesSubplot:title={'center':'dates'}>]], dtype=object)

# %% [markdown]
# Correlation

# %%
corr = df.corr()
corr
# Out:
#                       Infosys  Indian Hotel  Mahindra & Mahindra  Axis Bank  \
# Infosys              1.000000      0.795461             0.195053   0.837789
# Indian Hotel         0.795461      1.000000             0.410030   0.829801
# Mahindra & Mahindra  0.195053      0.410030             1.000000   0.193252
# Axis Bank            0.837789      0.829801             0.193252   1.000000
# SAIL                -0.479648     -0.156767             0.400131  -0.318087
# Shree Cement         0.757489      0.790911             0.239813   0.761522
# Sun Pharma          -0.645646     -0.680355            -0.127840  -0.523302
# Jindal Steel        -0.095364      0.145155             0.263296  -0.058390
# Idea Vodafone       -0.850325     -0.775013            -0.160497  -0.676477
# Jet Airways         -0.483300     -0.224433             0.315606  -0.437216
#
#                          SAIL  Shree Cement  Sun Pharma  Jindal Steel  \
# ...

# %% [markdown]
# Heatmap

# %%
plt.figure(figsize=(20,40))
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Multivariate Analysis

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# 2.1 Draw Stock Price Graph(Stock Price vs Time) for any 2 given stocks with inference

# %%
df.columns
# Out:
# Index(['Date', 'Infosys', 'Indian Hotel', 'Mahindra & Mahindra', 'Axis Bank',
#        'SAIL', 'Shree Cement', 'Sun Pharma', 'Jindal Steel', 'Idea Vodafone',
#        'Jet Airways', 'dates'],
#       dtype='object')

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x = "dates", y = "Jet Airways", data=df)
sns.set(font_scale=1)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x = "dates", y = "Idea Vodafone", data=df,)
sns.set(font_scale=1)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x = "dates", y = "Jindal Steel", data=df)
sns.set(font_scale=1)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x = "dates", y = "Sun Pharma", data=df)
sns.set(font_scale=1)
plt.show()

# %%
df.columns
# Out:
# Index(['Date', 'Infosys', 'Indian Hotel', 'Mahindra & Mahindra', 'Axis Bank',
#        'SAIL', 'Shree Cement', 'Sun Pharma', 'Jindal Steel', 'Idea Vodafone',
#        'Jet Airways', 'dates'],
#       dtype='object')

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x = "dates", y = "Shree Cement", data=df)
sns.set(font_scale=1)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x = "dates", y = "SAIL", data=df)
sns.set(font_scale=1)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x = "dates", y = "Axis Bank", data=df)
sns.set(font_scale=1)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x = "dates", y = "Mahindra & Mahindra", data=df)
sns.set(font_scale=1)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x = "dates", y = "Indian Hotel", data=df)
sns.set(font_scale=1)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x = "dates", y = "Infosys", data=df)
sns.set(font_scale=1)
plt.show()

# %% [markdown]
# 2.2 Calculate Returns for all stocks with inference

# %%
stock_returns_df = np.log(df.drop(['Date','dates'],axis=1)).diff(axis = 0, periods = 1)

# %%
stock_returns_df.shape
# Out:
# (314, 10)

# %%
stock_returns_df.head()
# Out:
#     Infosys  Indian Hotel  Mahindra & Mahindra  Axis Bank      SAIL  \
# 0       NaN           NaN                  NaN        NaN       NaN
# 1 -0.026873     -0.014599             0.006572   0.048247  0.028988
# 2 -0.011742      0.000000            -0.008772  -0.021979 -0.028988
# 3 -0.003945      0.000000             0.072218   0.047025  0.000000
# 4  0.011788     -0.045120            -0.012371  -0.003540 -0.076373
#
#    Shree Cement  Sun Pharma  Jindal Steel  Idea Vodafone  Jet Airways
# 0           NaN         NaN           NaN            NaN          NaN
# 1      0.032831    0.094491     -0.065882       0.011976     0.086112
# 2     -0.013888   -0.004930      0.000000      -0.011976    -0.078943
# 3      0.007583   -0.004955     -0.018084       0.000000     0.007117
# 4     -0.019515    0.011523     -0.140857      -0.049393    -0.148846

# %%
stock_returns_df
# Out:
#       Infosys  Indian Hotel  Mahindra & Mahindra  Axis Bank      SAIL  \
# 0         NaN           NaN                  NaN        NaN       NaN
# 1   -0.026873     -0.014599             0.006572   0.048247  0.028988
# 2   -0.011742      0.000000            -0.008772  -0.021979 -0.028988
# 3   -0.003945      0.000000             0.072218   0.047025  0.000000
# 4    0.011788     -0.045120            -0.012371  -0.003540 -0.076373
# ..        ...           ...                  ...        ...       ...
# 309  0.009649     -0.110348             0.030305  -0.057580 -0.087011
# 310 -0.139625     -0.051293            -0.093819  -0.145324 -0.095310
# 311 -0.094207     -0.236389            -0.285343  -0.284757 -0.105361
# 312  0.109856     -0.182322            -0.091269  -0.173019 -0.251314
# 313 -0.017228      0.000000            -0.031198   0.051432  0.090972
#
#      Shree Cement  Sun Pharma  Jindal Steel  Idea Vodafone  Jet Airways
# ...

# %% [markdown]
# 2.3 Calculate Stock Means and Standard Deviation for all stocks with inference

# %% [markdown]
# Stock Mean

# %%
stock_means_df = stock_returns_df.mean(axis = 0)
stock_means_df.sort_values(ascending=False)
# Out:
# Shree Cement           0.003681
# Infosys                0.002794
# Axis Bank              0.001167
# Indian Hotel           0.000266
# Sun Pharma            -0.001455
# Mahindra & Mahindra   -0.001506
# SAIL                  -0.003463
# Jindal Steel          -0.004123
# Jet Airways           -0.009548
# Idea Vodafone         -0.010608
# dtype: float64

# %% [markdown]
# Standard Deviation

# %%
stock_sd_df = stock_returns_df.std(axis = 0)
stock_sd_df.sort_values(ascending=False)
# Out:
# Idea Vodafone          0.104315
# Jet Airways            0.097972
# Jindal Steel           0.075108
# SAIL                   0.062188
# Indian Hotel           0.047131
# Axis Bank              0.045828
# Sun Pharma             0.045033
# Mahindra & Mahindra    0.040169
# Shree Cement           0.039917
# Infosys                0.035070
# dtype: float64

# %% [markdown]
# 2.4 Draw a plot of Stock Means vs Standard Deviation and state your inference

# %%
stock_returns_df.plot(figsize=(30,12)) 
plt.xlabel("Stock Prices") 
plt.ylabel("Cumulative Returns Last 6yrs") 
plt.title("Stock Price-Cumulative Return ")
plt.show()

# %%
plt.scatter(stock_means_df, stock_sd_df, edgecolors='g')
plt.xlabel('stock_means')
plt.ylabel('stock_sd')
plt.title('stock_means vs stock_sd')
plt.show()

# %%
df = pd.DataFrame({'Average':stock_means_df, 'Volatility': stock_sd_df})
df.sort_values(by=['Average'],ascending=False)
# Out:
#                       Average  Volatility
# Shree Cement         0.003681    0.039917
# Infosys              0.002794    0.035070
# Axis Bank            0.001167    0.045828
# Indian Hotel         0.000266    0.047131
# Sun Pharma          -0.001455    0.045033
# Mahindra & Mahindra -0.001506    0.040169
# SAIL                -0.003463    0.062188
# Jindal Steel        -0.004123    0.075108
# Jet Airways         -0.009548    0.097972
# Idea Vodafone       -0.010608    0.104315

# %%
df = pd.DataFrame({'Standard deviation':stock_sd_df, 'Volatility': stock_sd_df}) 
df.sort_values(by=['Volatility'],ascending=False)
# Out:
#                      Standard deviation  Volatility
# Idea Vodafone                  0.104315    0.104315
# Jet Airways                    0.097972    0.097972
# Jindal Steel                   0.075108    0.075108
# SAIL                           0.062188    0.062188
# Indian Hotel                   0.047131    0.047131
# Axis Bank                      0.045828    0.045828
# Sun Pharma                     0.045033    0.045033
# Mahindra & Mahindra            0.040169    0.040169
# Shree Cement                   0.039917    0.039917
# Infosys                        0.035070    0.035070
